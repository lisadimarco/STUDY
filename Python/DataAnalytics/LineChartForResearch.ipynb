# %% [markdown]
# You’re part of a meteorological research team, the Petrichor lab. Your team’s goal is to create data visualizations that help to compare different climate factors around the world.

# %% [markdown]
# #### 1. Import pandas and matplotlib to get started.

# %%
from matplotlib import pyplot as plt
import pandas as pd

# %%
# %matplotlib inline

# %% [markdown]
# #### 2. Load in the dataset `2020 monthly avg precipitation around the world - imperial.csv` using pandas. Check out the first few lines to make sure you know how the data is structured.

# %%
data = pd.read_csv("2020 monthly avg precipitation around the world - imperial.csv")
data.head()
# Out:
#    month_num month_name  london  windhoek  quito  kodiak  samarqand  \
# 0          1    january     2.0       2.7    4.1     7.2        3.1
# 1          2   february     1.5       3.3    5.1     6.5        3.3
# 2          3      march     1.3       2.3    5.8     4.9        2.5
# 3          4      april     1.3       1.3    6.3     3.6        1.4
# 4          5        may     1.4       0.2    3.8     2.7        0.7
#
#    alice_springs unit
# 0            1.5   in
# 1            1.5   in
# 2            1.1   in
# 3            0.7   in
# 4            0.6   in

# %% [markdown]
# #### 3. Write the code to make a line chart with months on the x-axis and Alice Springs precipitation data on the y-axis, then print the plot.

# %%
plt.plot(data.month_name, data.alice_springs)
plt.show()

# %% [markdown]
# #### 4. Write the code to add lines to the graph for the other five cities: Windhoek, Quito, Kodiak, Samarqand, and London.

# %%
plt.plot(data.month_name, data.alice_springs, color='green')
plt.plot(data.month_name, data.windhoek, color='yellowgreen')
plt.plot(data.month_name, data.quito, color='steelblue')
plt.plot(data.month_name, data.kodiak, color='chocolate')
plt.plot(data.month_name, data.samarqand, color='darkorange')
plt.plot(data.month_name, data.london, color='darkorange')



plt.show()

# %% [markdown]
# #### 5. Color the lines in the following groups based on hemisphere:
#
# * Alice Springs (`green`) and Windhoek (`yellowgreen`)
# * Quito (`steelblue`)
# * Kodiak (`chocolate`), Samarqand (`darkorange`) and London (also `darkorange`)
#
# (Samarqand and London have the same color because one will have a solid line and the other won’t.)

# %%
plt.plot(data.month_name, data.alice_springs, color='green')
plt.plot(data.month_name, data.windhoek, color='yellowgreen')
plt.plot(data.month_name, data.quito, color='steelblue')
plt.plot(data.month_name, data.kodiak, color='chocolate')
plt.plot(data.month_name, data.samarqand, color='darkorange')
plt.plot(data.month_name, data.london, color='darkorange')


plt.show()

# %% [markdown]
# #### 6. Assign line style to each location based on precipitation type:
#
# * Alice Springs, Windhoek, Quito, and London have rain (solid line)
# * Kodiak and Samarqand have rain and snow (dashed or dotted line)
#
# Choose whichever line style you prefer for Kodiak and Samarqand – just keep it the same for both.

# %%
plt.plot(data.month_name, data.alice_springs, color='green', linestyle='solid')
plt.plot(data.month_name, data.windhoek, color='yellowgreen', linestyle='solid')
plt.plot(data.month_name, data.quito, color='steelblue', linestyle='solid')
plt.plot(data.month_name, data.kodiak, color='chocolate', linestyle='dotted')
plt.plot(data.month_name, data.samarqand, color='darkorange', linestyle='dotted')
plt.plot(data.month_name, data.london, color='darkorange', linestyle='solid')


plt.show()

# %% [markdown]
# #### 7. Give the graph an appropriate title.

# %%
plt.plot(data.month_name, data.alice_springs, color='green', linestyle='solid')
plt.plot(data.month_name, data.windhoek, color='yellowgreen', linestyle='solid')
plt.plot(data.month_name, data.quito, color='steelblue', linestyle='solid')
plt.plot(data.month_name, data.kodiak, color='chocolate', linestyle='dotted')
plt.plot(data.month_name, data.samarqand, color='darkorange', linestyle='dotted')
plt.plot(data.month_name, data.london, color='darkorange', linestyle='solid')
plt.title('Monthly avg precipitation in 2020')

plt.show()

# %% [markdown]
# #### 8. Label the axes “Month” and “Precipitation (in.)”

# %%
plt.plot(data.month_name, data.alice_springs, color='green', linestyle='solid')
plt.plot(data.month_name, data.windhoek, color='yellowgreen', linestyle='solid')
plt.plot(data.month_name, data.quito, color='steelblue', linestyle='solid')
plt.plot(data.month_name, data.kodiak, color='chocolate', linestyle='dotted')
plt.plot(data.month_name, data.samarqand, color='darkorange', linestyle='dotted')
plt.plot(data.month_name, data.london, color='darkorange', linestyle='solid')
plt.title('Monthly avg precipitation in 2020')
plt.xlabel('Month')
plt.ylabel('Precipitation (in.)')


plt.show()

# %% [markdown]
# #### 9. Rotate the tick labels to improve their readability.

# %%
plt.plot(data.month_name, data.alice_springs, color='green', linestyle='solid')
plt.plot(data.month_name, data.windhoek, color='yellowgreen', linestyle='solid')
plt.plot(data.month_name, data.quito, color='steelblue', linestyle='solid')
plt.plot(data.month_name, data.kodiak, color='chocolate', linestyle='dotted')
plt.plot(data.month_name, data.samarqand, color='darkorange', linestyle='dotted')
plt.plot(data.month_name, data.london, color='darkorange', linestyle='solid')
plt.title('Monthly avg precipitation in 2020')
plt.xlabel('Month')
plt.ylabel('Precipitation (in.)')
plt.tick_params(axis='x', labelrotation=30)

plt.show()

# %% [markdown]
# #### 10. Create a legend and label the lines that it will show.

# %%
plt.plot(data.month_name, data.alice_springs, color='green', linestyle='solid', label='Alice Springs')
plt.plot(data.month_name, data.windhoek, color='yellowgreen', linestyle='solid', label='Windhoek')
plt.plot(data.month_name, data.quito, color='steelblue', linestyle='solid', label='Quito')
plt.plot(data.month_name, data.kodiak, color='chocolate', linestyle='dotted', label='Kodiak')
plt.plot(data.month_name, data.samarqand, color='darkorange', linestyle='dotted', label='Samarqand')
plt.plot(data.month_name, data.london, color='darkorange', linestyle='solid', label='London')
plt.title('Monthly avg precipitation in 2020')
plt.xlabel('Month')
plt.ylabel('Precipitation (in.)')
plt.tick_params(axis='x', labelrotation=30)
plt.legend(bbox_to_anchor = (1, 0.5))

plt.show()

# %% [markdown]
# #### 11. Position the legend by the bottom right-hand corner of the figure, making sure it lies outside the graph and doesn’t block any of the lines from view.

# %%
plt.plot(data.month_name, data.alice_springs, color='green', linestyle='solid', label='Alice Springs')
plt.plot(data.month_name, data.windhoek, color='yellowgreen', linestyle='solid', label='Windhoek')
plt.plot(data.month_name, data.quito, color='steelblue', linestyle='solid', label='Quito')
plt.plot(data.month_name, data.kodiak, color='chocolate', linestyle='dotted', label='Kodiak')
plt.plot(data.month_name, data.samarqand, color='darkorange', linestyle='dotted', label='Samarqand')
plt.plot(data.month_name, data.london, color='darkorange', linestyle='solid', label='London')
plt.title('Monthly avg precipitation in 2020')
plt.xlabel('Month')
plt.ylabel('Precipitation (in.)')
plt.tick_params(axis='x', labelrotation=30)
plt.legend(bbox_to_anchor = (1, 0.5))



plt.show()

# %% [markdown]
# #### 12. Use code to export your chart as a .png file.

# %%
plt.plot(data.month_name, data.alice_springs, color='green', linestyle='solid', label='Alice Springs')
plt.plot(data.month_name, data.windhoek, color='yellowgreen', linestyle='solid', label='Windhoek')
plt.plot(data.month_name, data.quito, color='steelblue', linestyle='solid', label='Quito')
plt.plot(data.month_name, data.kodiak, color='chocolate', linestyle='dotted', label='Kodiak')
plt.plot(data.month_name, data.samarqand, color='darkorange', linestyle='dotted', label='Samarqand')
plt.plot(data.month_name, data.london, color='darkorange', linestyle='solid', label='London')
plt.title('Monthly avg precipitation in 2020')
plt.xlabel('Month')
plt.ylabel('Precipitation (in.)')
plt.tick_params(axis='x', labelrotation=30)
plt.legend(bbox_to_anchor = (1, 0.5))

plt.show()
plt.savefig('my_graph')

# %% [markdown]
# <details>
#     <summary style="display:list-item; font-size:16px; color:blue;"><i>What did we discover? Toggle to check:</i></summary>
#
# Precipitation | Temperature
# :-: | :-:
# ![alt](project_line_chart1.png) | ![alt](temps_line_chart_project.png)
#
# Let's compare our results with the lab's earlier temperature graph for more context. **Take a minute to compare the graphs and then read on!**
#
# Overall, it looks like places with higher average temperatures have less precipitation, and vice versa.
#
# Quito, which has an almost identical month-to-month average high temperatures, experiences an extreme swing in seasonal precipitation.
#
# Conversely, London experiences a significant shift in month-to-month average high temperatures, but has fairly consistent precipitation.
#
# Kodiak has the most precipitation overall, only surpassed by Quito in the months of March, April, and May.
#
# Alice Springs has the least precipitation overall, although Samarqand and Windhoek both get _slightly_ less precipitation about half the months of the year.
#
# Although they are in different hemispheres, Samarqand and Windhoek have very similar monthly average precipitation patterns. Temperature-wise, Samarqand experiences the most extreme seasonal variation of all 6 cities, and Windhoek has relatively little temperature variation.
#     </details>

# %% [markdown]
# That's the end of this project -- nice work!
